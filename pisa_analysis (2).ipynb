# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("/content/pisadata.csv")

# %%
df.head()
# Out:
#    index LOCATION INDICATOR SUBJECT  TIME    Value
# 0      0      AUS  PISAMATH     BOY  2003  527.000
# 1      1      AUS  PISAMATH     BOY  2006  527.000
# 2      2      AUS  PISAMATH     BOY  2009  519.000
# 3      3      AUS  PISAMATH     BOY  2012  510.115
# 4      4      AUS  PISAMATH     BOY  2015  497.000

# %%
df.info
# Out:
# <bound method DataFrame.info of       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 0         0      AUS     PISAMATH     BOY  2003  527.000
# 1         1      AUS     PISAMATH     BOY  2006  527.000
# 2         2      AUS     PISAMATH     BOY  2009  519.000
# 3         3      AUS     PISAMATH     BOY  2012  510.115
# 4         4      AUS     PISAMATH     BOY  2015  497.000
# ...     ...      ...          ...     ...   ...      ...
# 2082   2082      CRI  PISASCIENCE     BOY  2018  420.000
# 2083   2083      CRI  PISASCIENCE    GIRL  2018  411.000
# 2084   2084      LTU  PISASCIENCE     TOT  2018  482.000
# 2085   2085      LTU  PISASCIENCE     BOY  2018  479.000
# 2086   2086      LTU  PISASCIENCE    GIRL  2018  485.000
#
# [2087 rows x 6 columns]>

# %%
df["INDICATOR"]
# Out:
# 0          PISAMATH
# 1          PISAMATH
# 2          PISAMATH
# 3          PISAMATH
# 4          PISAMATH
#            ...
# 2082    PISASCIENCE
# 2083    PISASCIENCE
# 2084    PISASCIENCE
# 2085    PISASCIENCE
# 2086    PISASCIENCE
# Name: INDICATOR, Length: 2087, dtype: object

# %%
df["INDICATOR"].value_counts()
# Out:
# PISAREAD       787
# PISAMATH       700
# PISASCIENCE    600
# Name: INDICATOR, dtype: int64

# %%
df["LOCATION"].value_counts()
# Out:
# AUS     54
# IRL     54
# SWE     54
# BRA     54
# PRT     54
# POL     54
# NOR     54
# NZL     54
# IDN     54
# MEX     54
# KOR     54
# JPN     54
# ITA     54
# ISL     54
# HUN     54
# GRC     54
# DEU     54
# FRA     54
# FIN     54
# DNK     54
# CZE     54
# CAN     54
# BEL     54
# CHE     54
# LUX     53
# TUR     51
# USA     51
# SVK     51
# ESP     51
# NLD     51
# OAVG    49
# CHL     48
# ISR     48
# RUS     47
# SVN     45
# GBR     45
# EST     45
# AUT     45
# LVA     30
# COL     18
# SGP      9
# HKG      9
# PER      9
# TWN      9
# MAC      9
# CRI      9
# LTU      9
# Name: LOCATION, dtype: int64

# %%
filt=(df["LOCATION"]=="TUR")
df.loc[filt]
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 322     322      TUR     PISAMATH     BOY  2003  430.000
# 323     323      TUR     PISAMATH     BOY  2006  427.000
# 324     324      TUR     PISAMATH     BOY  2009  451.000
# 325     325      TUR     PISAMATH     BOY  2012  451.934
# 326     326      TUR     PISAMATH     BOY  2015  423.000
# 327     327      TUR     PISAMATH     BOY  2018  456.000
# 328     328      TUR     PISAMATH    GIRL  2003  415.000
# 329     329      TUR     PISAMATH    GIRL  2006  421.000
# 330     330      TUR     PISAMATH    GIRL  2009  440.000
# 331     331      TUR     PISAMATH    GIRL  2012  443.948
# 332     332      TUR     PISAMATH    GIRL  2015  418.000
# 333     333      TUR     PISAMATH    GIRL  2018  451.000
# 607     607      TUR     PISAMATH     TOT  2003  423.000
# 608     608      TUR     PISAMATH     TOT  2006  424.000
# 609     609      TUR     PISAMATH     TOT  2009  445.000
# ...

# %%
filt = (df["LOCATION"] == "TUR") & (df["INDICATOR"]=="PISASCIENCE")
df.loc[filt]
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 1755   1755      TUR  PISASCIENCE     BOY  2006  418.000
# 1756   1756      TUR  PISASCIENCE     BOY  2009  448.000
# 1757   1757      TUR  PISASCIENCE     BOY  2012  458.316
# 1758   1758      TUR  PISASCIENCE     BOY  2015  422.000
# 1759   1759      TUR  PISASCIENCE     BOY  2018  465.000
# 1760   1760      TUR  PISASCIENCE    GIRL  2006  430.000
# 1761   1761      TUR  PISASCIENCE    GIRL  2009  460.000
# 1762   1762      TUR  PISASCIENCE    GIRL  2012  468.622
# 1763   1763      TUR  PISASCIENCE    GIRL  2015  429.000
# 1764   1764      TUR  PISASCIENCE    GIRL  2018  472.000
# 2001   2001      TUR  PISASCIENCE     TOT  2006  424.000
# 2002   2002      TUR  PISASCIENCE     TOT  2009  454.000
# 2003   2003      TUR  PISASCIENCE     TOT  2012  463.000
# 2004   2004      TUR  PISASCIENCE     TOT  2015  425.000
# 2005   2005      TUR  PISASCIENCE     TOT  2018  468.000

# %%
df[filt].sort_values("Value",ascending=False)
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 1764   1764      TUR  PISASCIENCE    GIRL  2018  472.000
# 1762   1762      TUR  PISASCIENCE    GIRL  2012  468.622
# 2005   2005      TUR  PISASCIENCE     TOT  2018  468.000
# 1759   1759      TUR  PISASCIENCE     BOY  2018  465.000
# 2003   2003      TUR  PISASCIENCE     TOT  2012  463.000
# 1761   1761      TUR  PISASCIENCE    GIRL  2009  460.000
# 1757   1757      TUR  PISASCIENCE     BOY  2012  458.316
# 2002   2002      TUR  PISASCIENCE     TOT  2009  454.000
# 1756   1756      TUR  PISASCIENCE     BOY  2009  448.000
# 1760   1760      TUR  PISASCIENCE    GIRL  2006  430.000
# 1763   1763      TUR  PISASCIENCE    GIRL  2015  429.000
# 2004   2004      TUR  PISASCIENCE     TOT  2015  425.000
# 2001   2001      TUR  PISASCIENCE     TOT  2006  424.000
# 1758   1758      TUR  PISASCIENCE     BOY  2015  422.000
# 1755   1755      TUR  PISASCIENCE     BOY  2006  418.000

# %%
filt=(df["LOCATION"]=="TUR")& (df["INDICATOR"]=="PISASCIENCE")&(df["SUBJECT"]=="GIRL")
df.loc[filt]
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 1760   1760      TUR  PISASCIENCE    GIRL  2006  430.000
# 1761   1761      TUR  PISASCIENCE    GIRL  2009  460.000
# 1762   1762      TUR  PISASCIENCE    GIRL  2012  468.622
# 1763   1763      TUR  PISASCIENCE    GIRL  2015  429.000
# 1764   1764      TUR  PISASCIENCE    GIRL  2018  472.000

# %%
filt2=(df["LOCATION"]=="FRA")&(df["INDICATOR"]=="PISASCIENCE")&(df["SUBJECT"]=="GIRL")
df.loc[filt2]
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 1560   1560      FRA  PISASCIENCE    GIRL  2006  494.000
# 1561   1561      FRA  PISASCIENCE    GIRL  2009  497.000
# 1562   1562      FRA  PISASCIENCE    GIRL  2012  500.157
# 1563   1563      FRA  PISASCIENCE    GIRL  2015  494.000
# 1564   1564      FRA  PISASCIENCE    GIRL  2018  493.000

# %%
df[filt2].sort_values("Value",ascending=False)
# Out:
#       index LOCATION    INDICATOR SUBJECT  TIME    Value
# 1562   1562      FRA  PISASCIENCE    GIRL  2012  500.157
# 1561   1561      FRA  PISASCIENCE    GIRL  2009  497.000
# 1560   1560      FRA  PISASCIENCE    GIRL  2006  494.000
# 1563   1563      FRA  PISASCIENCE    GIRL  2015  494.000
# 1564   1564      FRA  PISASCIENCE    GIRL  2018  493.000

# %%
df.loc[filt2,"Value"]
# Out:
# 1560    494.000
# 1561    497.000
# 1562    500.157
# 1563    494.000
# 1564    493.000
# Name: Value, dtype: float64

# %%
df.loc[filt,"Value"]
# Out:
# 1760    430.000
# 1761    460.000
# 1762    468.622
# 1763    429.000
# 1764    472.000
# Name: Value, dtype: float64

# %%
df.loc[filt,"TIME"]
# Out:
# 1760    2006
# 1761    2009
# 1762    2012
# 1763    2015
# 1764    2018
# Name: TIME, dtype: int64
